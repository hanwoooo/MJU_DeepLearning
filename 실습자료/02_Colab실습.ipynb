# %%
print("Hello World! 2025")
# Out:
# Hello World! 2025

# %% [markdown]
# 이 프로젝트는 무려 1과 2를 더하는 프로그램입니다.

# %% [markdown]
# **ㅁㅁㄴㄴㄴ**

# %%
1+2
# Out:
# 3

# %%
pwd
# Out:
# '/content'

# %%
# !id -a
# Out:
# uid=0(root) gid=0(root) groups=0(root)

# %% [markdown]
# 실습01 : 파이썬 프로그래밍

# %%
4+4
# Out:
# 8

# %%
8**3
# Out:
# 512

# %%
16**0.5
# Out:
# 4.0

# %%
import math
n = math.sqrt(9.0)
print(n)
# Out:
# 3.0

# %%
math.log(16, 2)
# Out:
# 4.0

# %%
math.cos(0)
# Out:
# 1.0

# %%
x = 5

if x > 0:
  a = 1
  if x > 3:
    a = 3
    b = 2
else:
  a = -1
  b = -2

c = a + b
print(c)
# Out:
# 5

# %% [markdown]
# 실습02 : Linux 명령 사용

# %%
# !ps
# Out:
#     PID TTY          TIME CMD
#       1 ?        00:00:00 docker-init
#       7 ?        00:00:02 node
#       9 ?        00:00:00 oom_monitor.sh
#      11 ?        00:00:00 run.sh
#      12 ?        00:00:00 kernel_manager_
#      41 ?        00:00:00 tail
#      47 ?        00:00:00 tail
#      61 ?        00:00:13 python3 <defunct>
#      62 ?        00:00:02 colab-fileshim.
#     111 ?        00:00:06 jupyter-server
#     112 ?        00:00:00 dap_multiplexer
#     309 ?        00:00:10 python3
#     330 ?        00:00:00 language_servic
#     336 ?        00:00:29 node
#    4602 ?        00:00:00 sleep
#    4603 ?        00:00:00 ps

# %%
# !pwd # 현재 디렉토리
# Out:
# /content

# %%
# !ls
# Out:
# gdrive	Oryctolagus_cuniculus_Rcdo.jpg	r.jpg  sample_data  test

# %%
# !rmdir test11
# !ls -al
# Out:
# rmdir: failed to remove 'test11': No such file or directory
# total 16
# drwxr-xr-x 1 root root 4096 Sep 11 01:25 .
# drwxr-xr-x 1 root root 4096 Sep 11 01:22 ..
# drwxr-xr-x 4 root root 4096 Sep  9 13:46 .config
# drwxr-xr-x 1 root root 4096 Sep  9 13:46 sample_data

# %%
# !cat /etc/issue.net
# Out:
# Ubuntu 22.04.4 LTS

# %%
# !cat /etc/passwd
# Out:
# root:x:0:0:root:/root:/bin/bash
# daemon:x:1:1:daemon:/usr/sbin:/usr/sbin/nologin
# bin:x:2:2:bin:/bin:/usr/sbin/nologin
# sys:x:3:3:sys:/dev:/usr/sbin/nologin
# sync:x:4:65534:sync:/bin:/bin/sync
# games:x:5:60:games:/usr/games:/usr/sbin/nologin
# man:x:6:12:man:/var/cache/man:/usr/sbin/nologin
# lp:x:7:7:lp:/var/spool/lpd:/usr/sbin/nologin
# mail:x:8:8:mail:/var/mail:/usr/sbin/nologin
# news:x:9:9:news:/var/spool/news:/usr/sbin/nologin
# uucp:x:10:10:uucp:/var/spool/uucp:/usr/sbin/nologin
# proxy:x:13:13:proxy:/bin:/usr/sbin/nologin
# www-data:x:33:33:www-data:/var/www:/usr/sbin/nologin
# backup:x:34:34:backup:/var/backups:/usr/sbin/nologin
# list:x:38:38:Mailing List Manager:/var/list:/usr/sbin/nologin
# irc:x:39:39:ircd:/run/ircd:/usr/sbin/nologin
# gnats:x:41:41:Gnats Bug-Reporting System (admin):/var/lib/gnats:/usr/sbin/nologin
# nobody:x:65534:65534:nobody:/nonexistent:/usr/sbin/nologin
# _apt:x:100:65534::/nonexistent:/usr/sbin/nologin
# ...

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0xffffffff
# cpu MHz		: 2000.164
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# ...

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13289424 kB
# MemFree:         9265604 kB
# MemAvailable:   12134868 kB
# Buffers:          103544 kB
# Cached:          2963604 kB
# SwapCached:            0 kB
# Active:           450632 kB
# Inactive:        3263620 kB
# Active(anon):       1584 kB
# Inactive(anon):   647692 kB
# Active(file):     449048 kB
# Inactive(file):  2615928 kB
# Unevictable:           8 kB
# Mlocked:               8 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:              2028 kB
# Writeback:             0 kB
# AnonPages:        647144 kB
# Mapped:           395400 kB
# Shmem:              2164 kB
# KReclaimable:      90456 kB
# Slab:             132312 kB
# SReclaimable:      90456 kB
# SUnreclaim:        41856 kB
# KernelStack:        5812 kB
# PageTables:        10664 kB
# SecPageTables:         0 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6644712 kB
# Committed_AS:    2649868 kB
# ...

# %%
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         113G   39G   74G  35% /
# tmpfs            64M     0   64M   0% /dev
# shm             5.7G     0  5.7G   0% /dev/shm
# /dev/root       2.0G  1.2G  775M  61% /usr/sbin/docker-init
# /dev/sda1        74G   42G   33G  56% /opt/bin/.nvidia
# tmpfs           6.4G  216K  6.4G   1% /var/colab
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware

# %%
# !nvidia-smi
# Out:
# Thu Sep 11 01:43:17 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   47C    P0             27W /   70W |     102MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pwd
# !ls
# !mkdir test
# Out:
# /content
# sample_data

# %%
# !ls -al
# Out:
# total 20
# drwxr-xr-x 1 root root 4096 Sep 11 01:25 .
# drwxr-xr-x 1 root root 4096 Sep 11 01:22 ..
# drwxr-xr-x 4 root root 4096 Sep  9 13:46 .config
# drwxr-xr-x 1 root root 4096 Sep  9 13:46 sample_data
# drwxr-xr-x 2 root root 4096 Sep 11 01:25 test

# %%
# %cd test
# !ls -al
# !pwd
# Out:
# /content/test
# total 8
# drwxr-xr-x 2 root root 4096 Sep 11 01:25 .
# drwxr-xr-x 1 root root 4096 Sep 11 01:25 ..
# /content/test

# %%
# %cd ..
# !pwd
# Out:
# /content
# /content

# %%
# !ls -al
# Out:
# total 20
# drwxr-xr-x 1 root root 4096 Sep 11 01:25 .
# drwxr-xr-x 1 root root 4096 Sep 11 01:22 ..
# drwxr-xr-x 4 root root 4096 Sep  9 13:46 .config
# drwxr-xr-x 1 root root 4096 Sep  9 13:46 sample_data
# drwxr-xr-x 2 root root 4096 Sep 11 01:25 test

# %%
# !wget https://upload.wikimedia.org/wikipedia/commons/1/1f/Oryctolagus_cuniculus_Rcdo.jpg
# !cp Oryctolagus_cuniculus_Rcdo.jpg r.jpg
# Out:
# --2025-09-11 01:44:35--  https://upload.wikimedia.org/wikipedia/commons/1/1f/Oryctolagus_cuniculus_Rcdo.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 185.15.59.240, 2a02:ec80:300:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|185.15.59.240|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1879147 (1.8M) [image/jpeg]
# Saving to: ‘Oryctolagus_cuniculus_Rcdo.jpg.1’
#
# Oryctolagus_cunicul 100%[===================>]   1.79M  --.-KB/s    in 0.07s
#
# 2025-09-11 01:44:35 (26.6 MB/s) - ‘Oryctolagus_cuniculus_Rcdo.jpg.1’ saved [1879147/1879147]

# %%
# !ls -al
# Out:
# total 5532
# drwxr-xr-x 1 root root    4096 Sep 11 01:44 .
# drwxr-xr-x 1 root root    4096 Sep 11 01:22 ..
# drwxr-xr-x 4 root root    4096 Sep  9 13:46 .config
# drwxr-xr-x 2 root root    4096 Sep 11 01:25 gdrive
# -rw-r--r-- 1 root root 1879147 Oct  4  2013 Oryctolagus_cuniculus_Rcdo.jpg
# -rw-r--r-- 1 root root 1879147 Oct  4  2013 Oryctolagus_cuniculus_Rcdo.jpg.1
# -rw-r--r-- 1 root root 1879147 Sep 11 01:44 r.jpg
# drwxr-xr-x 1 root root    4096 Sep  9 13:46 sample_data
# drwxr-xr-x 2 root root    4096 Sep 11 01:42 test

# %%
from IPython.display import Image
Image('r.jpg')

# %%
import sys
print(sys.version)
# Out:
# 3.12.11 (main, Jun  4 2025, 08:56:18) [GCC 11.4.0]

# %%
import tensorflow as tf
print(tf.__version__)

tf.test.gpu_device_name()
# Out:
# 2.19.0
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 10770884300669978303
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 14619377664
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 13020767025922499102
#  physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
#  xla_global_id: 416903419]

# %%
print?

# %% [markdown]
# 실습 03 : 구글 Drive 연결

# %%
# !pwd
# Out:
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir gdrive

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-4136189365.py in <cell line: 0>()
# ----> 1 drive.mount('/content/gdrive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
# !ls -al /content/drive/MyDrive/'Colab Notebooks'
# Out:
# total 2484
# -rw------- 1 root root 2542701 Sep 11 01:48 '02. Colab실습.ipynb'
# -rw------- 1 root root     306 Sep 11 01:20  Untitled

# %%
# !wget https://raw.githubusercontent.com/keras-team/keras/tf-keras/examples/mnist_cnn.py -P 'drive/MyDrive/Colab Notebooks'

# !cat 'drive/MyDrive/Colab Notebooks/mnist_cnn.py'

# !mkdir 'drive/MyDrive/Colab Notebooks/data'

# !wget https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/csv/datasets/Titanic.csv -P 'drive/MyDrive/Colab Notebooks/data'
# Out:
# --2025-09-11 01:49:39--  https://raw.githubusercontent.com/keras-team/keras/tf-keras/examples/mnist_cnn.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2270 (2.2K) [text/plain]
# Saving to: ‘drive/MyDrive/Colab Notebooks/mnist_cnn.py’
#
# mnist_cnn.py        100%[===================>]   2.22K  --.-KB/s    in 0.001s
#
# 2025-09-11 01:49:39 (1.63 MB/s) - ‘drive/MyDrive/Colab Notebooks/mnist_cnn.py’ saved [2270/2270]
#
# '''Trains a simple convnet on the MNIST dataset.
#
# Gets to 99.25% test accuracy after 12 epochs
# (there is still a lot of margin for parameter tuning).
# 16 seconds per epoch on a GRID K520 GPU.
# '''
#
# from __future__ import print_function
# import keras
# from keras.datasets import mnist
# ...

# %%
# !wget https://raw.githubusercontent.com/keras-team/keras/tf-keras/examples/mnist_cnn.py -P 'drive/MyDrive/Colab Notebooks'

# !cat 'drive/MyDrive/Colab Notebooks/mnist_cnn.py'
# Out:
# --2025-09-11 01:49:57--  https://raw.githubusercontent.com/keras-team/keras/tf-keras/examples/mnist_cnn.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2270 (2.2K) [text/plain]
# Saving to: ‘gdrive/My Drive/Colab Notebooks/mnist_cnn.py.1’
#
# mnist_cnn.py.1      100%[===================>]   2.22K  --.-KB/s    in 0s
#
# 2025-09-11 01:49:57 (57.2 MB/s) - ‘gdrive/My Drive/Colab Notebooks/mnist_cnn.py.1’ saved [2270/2270]
#
# '''Trains a simple convnet on the MNIST dataset.
#
# Gets to 99.25% test accuracy after 12 epochs
# (there is still a lot of margin for parameter tuning).
# 16 seconds per epoch on a GRID K520 GPU.
# '''
#
# from __future__ import print_function
# import keras
# from keras.datasets import mnist
# ...

# %%
# !python '/content/drive/MyDrive/Colab Notebooks/mnist_cnn.py'
# Out:
# 2025-09-11 01:50:59.686695: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1757555459.720006    7561 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1757555459.730052    7561 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1757555459.754642    7561 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# 예제1 : 이미지의 스타일 변경을 해보자
# https://colab.research.google.com/github/keras-team/keras-io/blob/master/examples/generative/ipynb/neural_style_transfer.ipynb

# %% [markdown]
# 실습04: https://github.com/rickiepark/deep-learning-with-python-notebooks
